# %%
pip install pgspecial
# Out:
# Collecting pgspecial
#   Downloading pgspecial-1.13.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: psycopg2>=2.7.4 in /usr/local/lib/python3.7/dist-packages (from pgspecial) (2.7.6.1)
# Requirement already satisfied: click>=4.1 in /usr/local/lib/python3.7/dist-packages (from pgspecial) (7.1.2)
# Requirement already satisfied: sqlparse>=0.1.19 in /usr/local/lib/python3.7/dist-packages (from pgspecial) (0.4.1)
# Installing collected packages: pgspecial
# Successfully installed pgspecial-1.13.0

# %%
#importar librerias
import os
from google.colab import drive
from pandas_profiling import ProfileReport
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pgspecial
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
#traer el archivo desde el drive hasta el entorno colab
drive.mount('/content/drive',force_remount=True)
os.chdir("/content/drive/My Drive/DS4A - Team 55/Team 55 DS4A/bases/csv_carga/") 
# !ls
# Out:
# Mounted at /content/drive
# 2020_DEFUNCIONES.csv  AH6800121_INS_cl.csv  MORBILIDAD.csv
# 2021_DEFUNCIONES.csv  AP6800121_INS.csv     MORTALIDAD_V1.csv
# 549_MORBILIDAD.csv    AU6800121_INS.csv     NACIDOS_VIVOS.csv
# 551_MORTALIDAD.csv    BAJO_PESO.csv
# AC6800121_INS.csv     CORONAVIRUS.csv

# %%
## Conectarse a ala base de datos
# %load_ext sql
# %sql postgresql://masterbmga:gW2ZmJhjCYhXkRHnHXpM@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: masterbmga@maternabmga'

# %%
# %%sql
# -- KILL CONNECTIONS TO THE DATABASE
#
# SELECT pg_terminate_backend(pg_stat_activity.pid)
# FROM pg_stat_activity
# WHERE pg_stat_activity.datname = 'maternabmga'
#   AND pid <> pg_backend_pid();
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS saludata.rpsconsulta (
#     NUMERO_DE_LA_FACTURA	TEXT,
#     CODIGO_DEL_PRESTADOR_DE_SERVICIOS_DE_SALUD	TEXT,
#     TIPO_DE_IDENTIFICACION_DEL_USUARIO	TEXT,
#     NUMERO_DE_IDENTIFICACION_DEL_USUARIO	TEXT,
#     FECHA_DE_LA_CONSULTA	TEXT,
#     NUMERO_DE_AUTORIZACION	TEXT,
#     CODIGO_DE_LA_CONSULTA	TEXT,
#     FINALIDAD_DE_LA_CONSULTA	INTEGER,
#     CAUSA_EXTERNA	INTEGER,
#     CODIGO_DEL_DIAGNOSTICO_PRINCIPAL	TEXT,
#     CODIGO_DEL_DIAGNOSTICO_RELACIONADO_1	TEXT,
#     CODIGO_DEL_DIAGNOSTICO_RELACIONADO_2	TEXT,
#     CODIGO_DEL_DIAGNOSTICO_RELACIONADO_3	TEXT,
#     TIPO_DE_DIAGNOSTICO_PRINCIPAL	TEXT,
#     VALOR_DE_LA_CONSULTA	TEXT,
#     VALOR_DE_LA_CUOTA_MODERADORA	TEXT,
#     VALOR_NETO_A_PAGAR	TEXT,
#     EXTRA1 TEXT,
#     EXTRA2 TEXT,
#     EXTRA3 TEXT,
#     EXTRA11 TEXT,
#     EXTRA21 TEXT,
#     EXTRA31 TEXT,
#     EXTRA12 TEXT
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.rpsconsulta from 'AC6800121_INS.csv' with (format CSV, header FALSE, delimiter ',');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-4c0927d4fc1c> in <module>()
#       1
# ----> 2 get_ipython().magic("sql \\copy saludata.rpsconsulta1 from 'AC6800121_INS.csv' with (format CSV, header FALSE, delimiter ',');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.rpshospitalizacion (
#     NUMERO_DE_LA_FACTURA	TEXT,
#     CODIGO_DEL_PRESTADOR_DE_SERVICIOS_DE_SALUD	TEXT,
#     TIPO_DE_DOCUMENTO_DE_IDENTIFICACION_DEL_USUARIO	TEXT,
#     NUMERO_DE_IDENTIFICACION_DEL_USUARIO_EN_EL_SISTEMA	TEXT,
#     VIA_DE_INGRESO_A_LA_INSTITUCION	TEXT,
#     FECHA_DE_INGRESO_DEL_USUARIO_A_LA_INSTITUCION	TEXT,
#     HORA_DE_INGRESO_DEL_USUARIO_A_LA_INSTITUCION	TIME,
#     NUMERO_DE_AUTORIZACION	TEXT,
#     CAUSA_EXTERNA	INTEGER,
#     DIAGNOSTICO_PRINCIPAL_DE_INGRESO	TEXT,
#     DIAGNOSTICO_PRINCIPAL_DE_EGRESO	TEXT,
#     DIAGNOSTICO_RELACIONADO_Nro_1_DE_EGRESO	TEXT,
#     DIAGNOSTICO_RELACIONADO_Nro_2_DE_EGRESO	TEXT,
#     DIAGNOSTICO_RELACIONADO_Nro_3_DE_EGRESO	TEXT,
#     DIAGNOSTICO_DE_LA_COMPLICACION	TEXT,
#     ESTADO_A_LA_SALIDA	TEXT,
#     DIAGNOSTICO_DE_LA_CAUSA_BASICA_DE_MUERTE	TEXT,
#     FECHA_DE_EGRESO_DEL_USUARIO_A_LA_INSTITUCION	TEXT,
#     HORA_DE_EGRESO_DEL_USUARIO_DE_LA_INSTITUCION	TIME,
#     Var_1	TEXT,
#     Var_2	TEXT,
#     Var_3	INTEGER,
#     Var_4	TEXT,
#     Var_5	INTEGER,
#     Var_6	INTEGER,
#     Var_7	TEXT
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.rpshospitalizacion from 'AH6800121_INS_cl.csv' with (format CSV, header FALSE, delimiter ',');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-35ddb77c0890> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.rpshospitalizacion1 from 'AH6800121_INS_cl.csv' with (format CSV, header FALSE, delimiter ',');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.rpsurgencias (
#   NUMERO_DE_LA_FACTURA	TEXT,
#   CODIGO_DEL_PRESTADOR_DE_SERVICIOS_DE_SALUD	TEXT,
#   TIPO_DE_IDENTIFICACION_DEL_USUARIO	TEXT,
#   NUMERO_DE_IDENTIFICACION_DEL_USUARIO_EN_EL_SISTEMA	TEXT,
#   FECHA_DE_INGRESO_DEL_USUARIO_A_OBSERVACION	TEXT,
#   HORA_DE_INGRESO_DEL_USUARIO_A_OBSERVACION	TIME,
#   NUMERO_DE_AUTORIZACION	TEXT,
#   CAUSA_EXTERNA	TEXT,
#   DIAGNOSTICO_DE_LA_SALIDA	TEXT,
#   DIAGNOSTICO_RELACIONADO_Nro_1_A_LA_SALIDA	TEXT,
#   DIAGNOSTICO_RELACIONADO_Nro_2_A_LA_SALIDA	TEXT,
#   DIAGNOSTICO_RELACIONADO_Nro_3_A_LA_SALIDA	TEXT,
#   DESTINO_DEL_USUARIO_A_LA_SALIDA_DE_OBSERVACION	TEXT,
#   ESTADO_A_LA_SALIDA	TEXT,
#   CAUSA_BASICA_DE_MUERTE_EN_URGENCIAS	TEXT,
#   FECHA_DE_LA_SALIDA_DEL_USUARIO_EN_OBSERVACION	TEXT,
#   HORA_DE_LA_SALIDA_DEL_USUARIO_EN_OBSERVACION	TEXT,
#     Var_1	TEXT,
#     Var_2	TEXT,
#     Var_3	INTEGER,
#     Var_4	TEXT,
#     Var_5	INTEGER,
#     Var_6	INTEGER,
#     Var_7	TEXT
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.rpsurgencias from 'AU6800121_INS.csv' with (format CSV, header FALSE, delimiter ',');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-5b464cb449f7> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.rpsurgencias111 from 'AU6800121_INS.csv' with (format CSV, header FALSE, delimiter ',');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.rpsprocedimientos (
#   NUMERO_DE_LA_FACTURA	TEXT,
#   CODIGO_DEL_PRESTADOR_DE_SERVICIOS_DE_SALUD	TEXT,
#   TIPO_DE_IDENTIFICACION_DEL_USUARIO	TEXT,
#   NUMERO_DE_IDENTIFICACION_DEL_USUARIO_EN_EL_SISTEMA	TEXT,
#   FECHA_DEL_PROCEDIMIENTO	TEXT,
#   NUMERO_DE_AUTORIZACION	TEXT,
#   CODIGO_DEL_PROCEDIMIENTO	INTEGER,
#   AMBITO_DE_REALIZACION_DEL_PROCEDIMIENTO	INTEGER,
#   FINALIDAD_DEL_PROCEDIMIENTO	INTEGER,
#   PERSONAL_QUE_ATIENDE	TEXT,
#   DIAGNOSTICO_PRINCIPAL	TEXT,
#   DIAGNOSTICO_RELACIONADO	TEXT,
#   COMPLICACION	TEXT,
#   FORMA_DE_REALIZACION_DEL_ACTO_QUIRURGICO	TEXT,
#   VALOR_DEL_PROCEDIMIENTO	TEXT,
#   Var_1	TEXT,
#   Var_2	TEXT,
#   Var_3	INTEGER,
#   Var_4	TEXT,
#   Var_5	TEXT,
#   Var_6	INTEGER,
#   Var_7	TEXT
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.rpsprocedimientos from 'AP6800121_INS.csv' with (format CSV, header FALSE, delimiter ';');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-854b78ea8781> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.rpsprocedimientos6 from 'AP6800121_INS.csv' with (format CSV, header FALSE, delimiter ';');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.morbilidad (
#   cod_eve	TEXT,
#   fec_not	TEXT,
#   semana	INTEGER,
#   anio	INTEGER,
#   cod_pre	TEXT,
#   cod_sub	TEXT,
#   pri_nom_	TEXT,
#   seg_nom_	TEXT,
#   pri_ape_	TEXT,
#   seg_ape_	TEXT,
#   tip_ide_	TEXT,
#   num_ide_	TEXT,
#   edad_	INTEGER,
#   uni_med_	INTEGER,
#   nacionali_	INTEGER,
#   nombre_nacionalidad	TEXT,
#   sexo_	TEXT,
#   cod_pais_o	INTEGER,
#   cod_dpto_o	TEXT,
#   cod_mun_o	INTEGER,
#   area_	INTEGER,
#   localidad_	TEXT,
#   cen_pobla_	TEXT,
#   vereda_	TEXT,
#   bar_ver_	TEXT,
#   dir_res_	TEXT,
#   ocupacion_	INTEGER,
#   tip_ss_	TEXT,
#   cod_ase_	TEXT,
#   per_etn_	INTEGER,
#   nom_grupo_	TEXT,
#   estrato_	INTEGER,
#   gp_discapa	INTEGER,
#   gp_desplaz	INTEGER,
#   gp_migrant	INTEGER,
#   gp_carcela	INTEGER,
#   gp_gestan	INTEGER,
#   sem_ges_	INTEGER,
#   gp_indigen	INTEGER,
#   gp_pobicbf	INTEGER,
#   gp_mad_com	INTEGER,
#   gp_desmovi	INTEGER,
#   gp_psiquia	INTEGER,
#   gp_vic_vio	INTEGER,
#   gp_otros	INTEGER,
#   fuente	INTEGER,
#   cod_pais_r	INTEGER,
#   cod_dpto_r	INTEGER,
#   cod_mun_r	INTEGER,
#   fec_con_	TEXT,
#   ini_sin_	TEXT,
#   tip_cas_	INTEGER,
#   pac_hos_	INTEGER,
#   fec_hos_	TEXT,
#   con_fin_	INTEGER,
#   fec_def_	TEXT,
#   ajuste_	TEXT,
#   telefono_	TEXT,
#   fecha_nto_	TEXT,
#   cer_def_	TEXT,
#   cbmte_	TEXT,
#   uni_modif	TEXT,
#   nuni_modif	TEXT,
#   fec_arc_xl	TEXT,
#   nom_dil_f_	TEXT,
#   tel_dil_f_	TEXT,
#   fec_aju_	TEXT,
#   nit_upgd	TEXT,
#   fm_fuerza	TEXT,
#   fm_unidad	TEXT,
#   fm_grado	TEXT,
#   version	TEXT,
#   pte_remtda	INTEGER,
#   codinst_r1	TEXT,
#   inst_refe1	TEXT,
#   codinst_r2	TEXT,
#   inst_refe2	TEXT,
#   tiem_remis	INTEGER,
#   num_gestac	INTEGER,
#   num_parvag	INTEGER,
#   num_cesare	INTEGER,
#   num_aborto	INTEGER,
#   num_molas	INTEGER,
#   num_ectopi	INTEGER,
#   num_muerto	INTEGER,
#   num_vivos	INTEGER,
#   fec_ul_ges	TEXT,
#   no_con_pre	INTEGER,
#   sem_c_pren	INTEGER,
#   term_gesta	INTEGER,
#   moc_rel_tg	INTEGER,
#   falla_card	INTEGER,
#   falla_rena	INTEGER,
#   falla_hepa	INTEGER,
#   falla_cere	INTEGER,
#   falla_resp	INTEGER,
#   falla_coag	INTEGER,
#   eclampsia	INTEGER,
#   preclampsi	INTEGER,
#   choq_septi	INTEGER,
#   hemorragia_obstetrica_severa	INTEGER,
#   rupt_uteri	INTEGER,
#   cir_adicio	INTEGER,
#   ttl_criter	INTEGER,
#   cir_adic_1	INTEGER,
#   adic1_otro	TEXT,
#   cir_adic_2	INTEGER,
#   adic2_otro	TEXT,
#   fec_egreso	TEXT,
#   dias_hospi	INTEGER,
#   egreso	INTEGER,
#   caus_princ	TEXT,
#   caus_agrup	INTEGER,
#   caus_asoc1	TEXT,
#   caus_asoc2	TEXT,
#   caus_asoc3	TEXT,
#   peso_rnacx	INTEGER,
#   peso_rnacd	INTEGER,
#   emb_mult	TEXT,
#   estado_rna	TEXT,
#   ed_ter_ges	INTEGER,
#   regul_fecu	TEXT,
#   aborto_sep	TEXT,
#   emb_ectopi	TEXT,
#   autoinmune	TEXT,
#   hematologi	TEXT,
#   oncologica	TEXT,
#   endoc_meta	TEXT,
#   renales	TEXT,
#   gastrointe	TEXT,
#   eve_trombo	TEXT,
#   card_cereb	TEXT,
#   otras_enfe	TEXT,
#   accidente	TEXT,
#   enfe_molar	TEXT,
#   intox_acci	TEXT,
#   inten_suic	TEXT,
#   vic_violen	TEXT,
#   otros_even	TEXT,
#   cual_event	TEXT,
#   ingres_uci	TEXT,
#   transfusio	TEXT,
#   unds_trans	INTEGER,
#   falla_meta	TEXT,
#   dias_c_int	INTEGER,
#   nom_eve	TEXT,
#   nom_upgd	TEXT,
#   npais_proce	TEXT,
#   ndep_proce	TEXT,
#   nmun_proce	TEXT,
#   npais_resi	TEXT,
#   ndep_resi	TEXT,
#   nmun_resi	TEXT,
#   ndep_notif	TEXT,
#   nmun_notif	TEXT,
#   nreg	INTEGER
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.morbilidad from '549_MORBILIDAD.csv' with (format CSV, header FALSE, delimiter ';');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-4638e3f4f294> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.morbilidad1 from '549_MORBILIDAD.csv' with (format CSV, header FALSE, delimiter ';');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.coronavirus(
#   cod_eve	TEXT,
#   fec_not	TEXT,
#   semana	INTEGER,
#   anio	INTEGER,
#   cod_pre	TEXT,
#   cod_sub	INTEGER,
#   pri_nom_	TEXT,
#   seg_nom_	TEXT,
#   pri_ape_	TEXT,
#   seg_ape_	TEXT,
#   tip_ide_	TEXT,
#   num_ide_	TEXT,
#   edad_	INTEGER,
#   uni_med_	INTEGER,
#   unidedad	INTEGER,
#   nacionali_	INTEGER,
#   nombre_nacionalidad	TEXT,
#   sexo_	TEXT,
#   cod_pais_o	INTEGER,
#   cod_dpto_o	TEXT,
#   cod_mun_o	INTEGER,
#   area_	INTEGER,
#   localidad_	TEXT,
#   cen_pobla_	TEXT,
#   vereda_	TEXT,
#   bar_ver_	TEXT,
#   NUMERO_COMUNA	INTEGER,
#   NOMCOMUNA	TEXT,
#   COMUNA	TEXT,
#   dir_res_	TEXT,
#   ocupacion_	TEXT,
#   tip_ss_	TEXT,
#   cod_ase_	TEXT,
#   NOMBRE_EPS	TEXT,
#   per_etn_	TEXT,
#   nom_grupo_	TEXT,
#   estrato	TEXT,
#   gp_discapa	INTEGER,
#   gp_desplaz	INTEGER,
#   gp_migrant	INTEGER,
#   gp_carcela	INTEGER,
#   gp_gestan	INTEGER,
#   sem_ges	INTEGER,
#   gp_indigen	INTEGER,
#   gp_pobicbf	INTEGER,
#   gp_mad_com	INTEGER,
#   gp_desmovi	INTEGER,
#   gp_psiquia	INTEGER,
#   gp_vic_vio	INTEGER,
#   gp_otros	INTEGER,
#   fuente	TEXT,
#   cod_dpto_r	INTEGER,
#   cod_mun_r	INTEGER,
#   fec_con_	TEXT,
#   ini_sin_	TEXT,
#   tip_cas_	INTEGER,
#   pac_hos_	INTEGER,
#   fec_hos_	TEXT,
#   con_fin_	INTEGER,
#   fec_def_	TEXT,
#   ajuste_	INTEGER,
#   telefono_	TEXT,
#   fecha_nto_	TEXT,
#   cer_def_	TEXT,
#   cbmte_	TEXT,
#   uni_modif	TEXT,
#   nuni_modif	TEXT,
#   fec_arc_xl	TEXT,
#   nom_dil_f_	TEXT,
#   tel_dil_f_	TEXT,
#   fec_aju_	TEXT,
#   nit_upgd	TEXT,
#   fm_fuerza	TEXT,
#   fm_unidad	TEXT,
#   fm_grado	TEXT,
#   version	TEXT,
#   trab_salud	INTEGER,
#   deter_clin	TEXT,
#   asoc_brote	TEXT,
#   viajo	INTEGER,
#   municipio	TEXT,
#   codpais_pr	INTEGER,
#   internal	TEXT,
#   con_con	TEXT,
#   con_est	TEXT,
#   tos	INTEGER,
#   fiebre	INTEGER,
#   odinofagia	INTEGER,
#   dif_res	INTEGER,
#   adinamia	INTEGER,
#   vac_ei	TEXT,
#   dos_ei	TEXT,
#   asma	INTEGER,
#   epoc	INTEGER,
#   diabetes	INTEGER,
#   vih	INTEGER,
#   enf_card	INTEGER,
#   cancer	INTEGER,
#   desnutricion	INTEGER,
#   obesidad	INTEGER,
#   ins_renal	INTEGER,
#   otr_medinm	INTEGER,
#   fumador	INTEGER,
#   tuberculos	INTEGER,
#   otros_dc	INTEGER,
#   cual_ot_dc	TEXT,
#   hallaz_rad	TEXT,
#   uso_antib	TEXT,
#   uso_antiv	TEXT,
#   fec_antiv	TEXT,
#   serv_hosp	INTEGER,
#   fec_inguci	TEXT,
#   der_ple	TEXT,
#   der_per	TEXT,
#   miocarditi	TEXT,
#   septicemia	TEXT,
#   falla_resp	TEXT,
#   otros	TEXT,
#   pre_car_v1	TEXT,
#   vac_sp	TEXT,
#   dos_sp	TEXT,
#   fud_sp	TEXT,
#   fud_ei	TEXT,
#   dol_gar	TEXT,
#   rinorrea	TEXT,
#   conjuntivi	TEXT,
#   cefalea	TEXT,
#   diarrea	TEXT,
#   rx_torax	TEXT,
#   fec_tom_ra	TEXT,
#   fec_atib	TEXT,
#   otros_cual	TEXT,
#   dx_ini	TEXT,
#   dx_egr	TEXT,
#   semana_ges	TEXT,
#   nom_eve	TEXT,
#   nom_upgd	TEXT,
#   ndep_proce	TEXT,
#   nmun_proce	TEXT,
#   ndep_resi	TEXT,
#   nmun_resi	TEXT,
#   ndep_notif	TEXT,
#   nmun_notif	TEXT,
#   nreg	INTEGER,
#   activo	TEXT
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.coronavirus from 'CORONAVIRUS.csv' with (format CSV, header FALSE, delimiter ';');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-1256767248a3> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.coronavirus6 from 'CORONAVIRUS.csv' with (format CSV, header FALSE, delimiter ';');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.mortalidad(
#   cod_eve	TEXT,
#   fec_not	TEXT,
#   semana	INTEGER,
#   anio	INTEGER,
#   cod_pre	TEXT,
#   cod_sub	TEXT,
#   pri_nom_	TEXT,
#   seg_nom_	TEXT,
#   pri_ape_	TEXT,
#   seg_ape_	TEXT,
#   tip_ide_	TEXT,
#   num_ide_	TEXT,
#   edad_	INTEGER,
#   uni_med_	INTEGER,
#   nacionali_	INTEGER,
#   nombre_nacionalidad	TEXT,
#   sexo_	TEXT,
#   cod_pais_o	INTEGER,
#   cod_dpto_o	INTEGER,
#   cod_mun_o	TEXT,
#   area_	INTEGER,
#   localidad_	TEXT,
#   cen_pobla_	TEXT,
#   vereda_	TEXT,
#   bar_ver_	TEXT,
#   dir_res_ TEXT,
#   ocupacion_	INTEGER,
#   tip_ss_	TEXT,
#   cod_ase_	TEXT,
#   per_etn_	INTEGER,
#   nom_grupo_ TEXT,
#   estrato_	INTEGER,
#   gp_discapa	INTEGER,
#   gp_desplaz	INTEGER,
#   gp_migrant	INTEGER,
#   gp_carcela	INTEGER,
#   gp_gestan	INTEGER,
#   sem_ges_	INTEGER,
#   gp_indigen	INTEGER,
#   gp_pobicbf	INTEGER,
#   gp_mad_com	INTEGER,
#   gp_desmovi	INTEGER,
#   gp_psiquia	INTEGER,
#   gp_vic_vio	INTEGER,
#   gp_otros	INTEGER,
#   fuente_	INTEGER,
#   cod_pais_r	INTEGER,
#   cod_dpto_r	INTEGER,
#   cod_mun_r	INTEGER,
#   fec_con_	TEXT,
#   ini_sin_	TEXT,
#   tip_cas_	TEXT,
#   pac_hos_	INTEGER,
#   fec_hos_	TEXT,
#   con_fin_	TEXT,
#   fec_def_	TEXT,
#   ajuste_	TEXT,
#   telefono_	TEXT,
#   fecha_nto_	TEXT,
#   cer_def_	TEXT,
#   cbmte_	TEXT,
#   uni_modif	TEXT,
#   nuni_modif	TEXT,
#   fec_arc_xl	TEXT,
#   nom_dil_f_	TEXT,
#   tel_dil_f_	TEXT,
#   fec_aju_	TEXT,
#   nit_upgd	TEXT,
#   fm_fuerza	TEXT,
#   fm_unidad	TEXT,
#   fm_grado	TEXT,
#   version	TEXT,
#   nom_eve	TEXT,
#   nom_upgd	TEXT,
#   npais_proce	TEXT,
#   ndep_proce	TEXT,
#   nmun_proce	TEXT,
#   npais_resi	TEXT,
#   ndep_resi	TEXT,
#   nmun_resi	TEXT,
#   ndep_notif	TEXT,
#   nmun_notif	TEXT,
#   nreg	INTEGER
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.mortalidad from '551_MORTALIDAD.csv' with (format CSV, header FALSE, delimiter ';');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-fc34df4d7465> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.mortalidad from '551_MORTALIDAD.csv' with (format CSV, header FALSE, delimiter ';');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.nacidos_vivos(
#   NUMERO_CERTIFICADO TEXT,
#   DEPARTAMENTO	TEXT,
#   MUNICIPIO	TEXT,
#   AREA_NACIMIENTO	TEXT,
#   INSPECCION_CORREGIMIENTO_O_CASERIO_NACIMIENTO	TEXT,
#   SITIO_NACIMIENTO	TEXT,
#   CODIGO_INSTITUCION	TEXT,
#   NOMBRE_INSTITUCION	TEXT,
#   SEXO	TEXT,
#   PESO_GRAMOS	INTEGER,
#   TALLA_CENTIMETROS	INTEGER,
#   FECHA_NACIMIENTO	TEXT,
#   HORA_NACIMIENTO	TEXT,
#   PARTO_ATENDIDO_POR	TEXT,
#   TIEMPO_DE_GESTACION	INTEGER,
#   NUMERO_CONSULTAS_PRENATALES	INTEGER,
#   TIPO_PARTO	TEXT,
#   MULTIPLICIDAD_EMBARAZO	TEXT,
#   APGAR1	TEXT,
#   APGAR2	TEXT,
#   GRUPO_SANGUINEO	TEXT,
#   FACTOR_RH	TEXT,
#   PERTENENCIA_ETNICA	TEXT,
#   GRUPO_INDIGENA	TEXT,
#   NOMBRES_MADRE	 TEXT,
#   APELLIDOS_MADRE	TEXT,
#   TIPO_DOCUMENTO_MADRE	TEXT,
#   NUMERO_DOCUMENTO_MADRE	TEXT,
#   EDAD_MADRE	TEXT,
#   ESTADO_CONYUGAL_MADRE	TEXT,
#   NIVEL_EDUCATIVO_MADRE	TEXT,
#   ULTIMO_AÑO_APROBADO_MADRE	INTEGER,
#   PAIS_RESIDENCIA	TEXT,
#   DEPARTAMENTO_RESIDENCIA	TEXT,
#   MUNICIPIO_RESIDENCIA	TEXT,
#   AREA_RESIDENCIA	TEXT,
#   LOCALIDAD	TEXT,
#   BARRIO	TEXT,
#   DIRECCION	TEXT,
#   CENTRO_POBLADO	TEXT,
#   RURAL_DISPERSO	TEXT,
#   NUMERO_HIJOS_NACIDOS_VIVOS	INTEGER,
#   FECHA_ANTERIOR_HIJO_NACIDO_VIVO	TEXT,
#   NUMERO_EMBARAZOS	INTEGER,
#   REGIMEN_SEGURIDAD	TEXT,
#   TIPO_ADMINISTRADORA	TEXT,
#   NOMBRE_ADMINISTRADORA	TEXT,
#   EDAD_PADRE	TEXT,
#   NIVEL_EDUCATIVO_PADRE	TEXT,
#   ULTIMO_AÑO_APROBADO_PADRE	INTEGER,
#   NOMBRES_Y_APELLIDOS_CERTIFICADOR TEXT,
#   NUMERO_DOCUMENTO_CERTIFICADOR	TEXT,
#   TIPO_DOCUMENTO_CERTIFICADOR	TEXT,
#   PROFESION_CERTIFICADOR	TEXT,
#   REGISTRO_PROFESIONAL_CERTIFICADOR	TEXT,
#   DEPARTAMENTO_EXPEDICION	TEXT,
#   MUNICIPIO_EXPEDICION	TEXT,
#   FECHA_EXPEDICION	TEXT,
#   ESTADO_CERTIFICADO	TEXT,
#   CODIGO_ENTIDAD_REGISTRO	TEXT,
#   USUARIO_REGISTRO	TEXT,
#   ULTIMA_FECHA_MODIFICACION	TEXT,
#   FECHA_REGISTRO	TEXT
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.nacidos_vivos from 'NACIDOS_VIVOS.csv' with (format CSV, header FALSE, delimiter ';');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-91c3ac70e696> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.nacidos_vivos1 from 'NACIDOS_VIVOS.csv' with (format CSV, header FALSE, delimiter ';');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS saludata.bajo_peso(
#   cod_eve	TEXT,
#   fec_not	TEXT,
#   semana	INTEGER,
#   año	TEXT,
#   cod_pre	TEXT,
#   cod_sub	TEXT,
#   pri_nom_	TEXT,
#   seg_nom_	TEXT,
#   pri_ape_	TEXT,
#   seg_ape_	TEXT,
#   tip_ide_	TEXT,
#   num_ide_	TEXT,
#   edad_	INTEGER,
#   uni_med_	TEXT,
#   nacionali_	INTEGER,
#   nombre_nacionalidad	TEXT,
#   sexo_	TEXT,
#   cod_pais_o	TEXT,
#   cod_dpto_o	INTEGER,
#   cod_mun_o	INTEGER,
#   area_	INTEGER,
#   localidad_	TEXT,
#   cen_pobla_	TEXT,
#   vereda_	TEXT,
#   bar_ver_	TEXT,
#   dir_res_	TEXT,
#   ocupacion_	INTEGER,
#   tip_ss_	TEXT,
#   cod_ase_	TEXT,
#   per_etn_	TEXT,
#   nom_grupo_	TEXT,
#   estrato_	TEXT,
#   gp_discapa	TEXT,
#   gp_desplaz	TEXT,
#   gp_migrant	INTEGER,
#   gp_carcela	TEXT,
#   gp_gestan	INTEGER,
#   sem_ges_	INTEGER,
#   gp_indigen	TEXT,
#   gp_pobicbf	TEXT,
#   gp_mad_com	TEXT,
#   gp_desmovi	TEXT,
#   gp_psiquia	TEXT,
#   gp_vic_vio	TEXT,
#   gp_otros	INTEGER,
#   fuente	TEXT,
#   cod_pais_r	TEXT,
#   cod_dpto_r	INTEGER,
#   cod_mun_r	INTEGER,
#   fec_con_	TEXT,
#   ini_sin_	TEXT,
#   tip_cas_	TEXT,
#   pac_hos_	INTEGER,
#   fec_hos_	TEXT,
#   con_fin_	TEXT,
#   fec_def_	TEXT,
#   ajuste_	TEXT,
#   telefono_	TEXT,
#   fecha_nto_	TEXT,
#   cer_def_	TEXT,
#   cbmte_	TEXT,
#   uni_modif	TEXT,
#   nuni_modif	TEXT,
#   fec_arc_xl	TEXT,
#   nom_dil_f_	TEXT,
#   tel_dil_f_	TEXT,
#   fec_aju_	TEXT,
#   nit_upgd	TEXT,
#   fm_fuerza	TEXT,
#   fm_unidad	TEXT,
#   fm_grado	TEXT,
#   version	TEXT,
#   est_ingr	TEXT,
#   tip_doc_rn	TEXT,
#   no_ide_rn	TEXT,
#   fecha_nac	TEXT,
#   edad_rn	INTEGER,
#   sexo	TEXT,
#   peso_nacer	TEXT,
#   talla_nace	TEXT,
#   sem_gest	INTEGER,
#   cla_pes_na	TEXT,
#   sit_ate_pa	TEXT,
#   mult_embar	INTEGER,
#   num_em_pre	INTEGER,
#   num_hi_viv	INTEGER,
#   niv_edu_ma	INTEGER,
#   inv_campo	TEXT,
#   visita_efe	TEXT,
#   fec_iec	TEXT,
#   ent_re_iec	TEXT,
#   pro_re_iec	TEXT,
#   prof_r_iec	TEXT,
#   nom_sum_in	TEXT,
#   parent_rn	TEXT,
#   menor_aseg	TEXT,
#   nom_rec_na	TEXT,
#   seg_nom_rn	TEXT,
#   ape_rec_na	TEXT,
#   seg_ape_rn	TEXT,
#   hubo_contr	TEXT,
#   edad_ges	TEXT,
#   no_con_pre	TEXT,
#   calcio	TEXT,
#   sulfato_fe	TEXT,
#   aci_folico	TEXT,
#   anemia	TEXT,
#   ult_hemo_m	TEXT,
#   trim_g_cor	TEXT,
#   per_int_m2	TEXT,
#   h_ante_bpn	TEXT,
#   hta	TEXT,
#   part_pret	TEXT,
#   beb_alcoh	TEXT,
#   activ_dia	TEXT,
#   ivu	TEXT,
#   diag_sobre	TEXT,
#   diag_desnu	TEXT,
#   pes_preges	TEXT,
#   tall_mad	TEXT,
#   peso_ganad	TEXT,
#   estrato	TEXT,
#   agua_pot	TEXT,
#   eva_con_hi	TEXT,
#   ins_salud	TEXT,
#   peso_act	TEXT,
#   long_act	TEXT,
#   est_act_pe	TEXT,
#   lact_mat	TEXT,
#   ali_dif_24	TEXT,
#   leche_for	TEXT,
#   dif_lac_ma	TEXT,
#   capacitac	TEXT,
#   educ_alim	TEXT,
#   rem_serv	TEXT,
#   canal_apoy	TEXT,
#   est_ingr_	TEXT,
#   nom_eve	TEXT,
#   nom_upgd	TEXT,
#   npais_proce	TEXT,
#   ndep_proce	TEXT,
#   nmun_proce	TEXT,
#   npais_resi	TEXT,
#   ndep_resi	TEXT,
#   nmun_resi	TEXT,
#   ndep_notif	TEXT,
#   nmun_notif	TEXT,
#   nreg	INTEGER
#  );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.bajo_peso from 'BAJO_PESO.csv' with (format CSV, header FALSE, delimiter ';');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-172-c378a29b1b73> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.bajo_peso5 from 'BAJO_PESO.csv' with (format CSV, header FALSE, delimiter ';');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %%
## CARGA DEFUNCIONES
# %%sql
CREATE TABLE IF NOT EXISTS saludata.defunciones1(
    NUMERO_CERTIFICADO	TEXT,
    DEPARTAMENTO	TEXT,
    MUNICIPIO	TEXT,
    AREA_DEFUNCION	TEXT,
    INSPECCION_CORREGIMIENTO_O_CASERIO_DEFUNCION	TEXT,
    SITIO_DEFUNCION	TEXT,
    CODIGO_INSTITUCION	TEXT,
    NOMBRE_INSTITUCION	TEXT,
    TIPO_DEFUNCION	TEXT,
    FECHA_DEFUNCION	TEXT,
    HORA_DEFUNCION	TEXT,
    SEXO_FALLECIDO	TEXT,
    TIPO_DOCUMENTO_FALLECIDO	TEXT,
    NUMERO_DOCUMENTO_FALLECIDO	TEXT,
    FECHA_NACIMIENTO_FALLECIDO	TEXT,
    ESTADO_CONYUGAL_FALLECIDO	TEXT,
    EDAD_FALLECIDO	TEXT,
    NIVEL_EDUCATIVO_FALLECIDO	TEXT,
    ULTIMO_ANIO_APROBADO_FALLECIDO	TEXT,
    OCUPACION_FALLECIDO	TEXT,
    PERTENENCIA_ETNICA	TEXT,
    GRUPO_INDIGENA	TEXT,
    PAIS_RESIDENCIA	TEXT,
    DEPARTAMENTO_RESIDENCIA	TEXT,
    MUNICIPIO_RESIDENCIA	TEXT,
    AREA_RESIDENCIA	TEXT,
    LOCALIDAD	TEXT,
    BARRIO	TEXT,
    DIRECCION	TEXT,
    CENTRO_POBLADO	TEXT,
    RURAL_DISPERSO	TEXT,
    REGIMEN_SEGURIDAD	TEXT,
    TIPO_ADMINISTRADORA	TEXT,
    NOMBRE_ADMINISTRADORA	TEXT,
    PROBABLE_MANERA_MUERTE	TEXT,
    EXPEDIDO_POR	TEXT,
    RELACION_MUERTE_PARTO	TEXT,
    TIPO_PARTO	TEXT,
    MULTIPLICIDAD	TEXT,
    TIEMPO_GESTACION	TEXT,
    PESO_FETO	INTEGER,
    TIPO_DOCUMENTO_MADRE	TEXT,
    NUMERO_DOCUMENTO_MADRE	TEXT,
    NOMBRES_MADRE	TEXT,
    APELLIDOS_MADRE	TEXT,
    EDAD_MADRE	TEXT,
    HIJOS_NACIDOS_VIVOS	INTEGER,
    HIJOS_NACIDOS_MUERTOS	INTEGER,
    ESTADO_CONYUGAL_MADRE	TEXT,
    NIVEL_EDUCATIVO_MADRE	TEXT,
    ULTIMO_ANIO_APROBADO_MADRE	INTEGER,
    EMBARAZADA_CUANDO_FALLECIO	TEXT,
    EMBARAZADA_ULTIMAS_6_SEMANAS	TEXT,
    EMBARAZADA_ULTIMOS_12_MESES	TEXT,
    TIPO_MUERTE_VIOLENTA	TEXT,
    DESCRIPCION_MUERTE_VIOLENTA	TEXT,
    DEPARTAMENTO_MUERTE_VIOLENTA	TEXT,
    MUNICIPIO_MUERTE_VIOLENTA	TEXT,
    DIRECCION_MUERTE_VIOLENTA	TEXT,
    MECANISMO_1	TEXT,
    MECANISMO_2	TEXT,
    MECANISMO_3	TEXT,
    MECANISMO_4	TEXT,
    RECIBIO_ASISTENCIA_MEDICA	TEXT,
    CAUSA_DIRECTA	TEXT,
    CAUSA_ANTECEDENTES_B	TEXT,
    CAUSA_ANTECEDENTES_C	TEXT,
    CAUSA_ANTECEDENTES_D	TEXT,
    ESTADOS_PATOLOGICOS	TEXT,
    CAUSA_BASICA	TEXT,
    MUERTE_SIN_CERTIFICACION_MEDICA	TEXT,
    NOMBRES_Y_APELLIDOS_CERTIFICADOR	TEXT,
    TIPO_DOCUMENTO_CERTIFICADOR	TEXT,
    NUMERO_DOCUMENTO_CERTIFICADOR	TEXT,
    TIPO_PROFESIONAL	TEXT,
    REGISTRO_PROFESIONAL	TEXT,
    DEPARTAMENTO_EXPEDICION	TEXT,
    MUNICIPIO_EXPEDICION	TEXT,
    FECHA_EXPEDICION	TEXT,
    ESTADO_CERTIFICADO	TEXT,
    CODIGO_ENTIDAD_REGISTRO	TEXT,
    USUARIO_REGISTRO	TEXT,
    ULTIMA_FECHA_MODIFICACION	TEXT,
    FECHA_REGISTRO	TEXT
 );
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# []

# %%
# %sql \copy saludata.defunciones1 from '2020_DEFUNCIONES.csv' with (format CSV, header FALSE, delimiter ';');

# %%
# %sql \copy saludata.defunciones1 from '2021_DEFUNCIONES.csv' with (format CSV, header FALSE, delimiter ';');
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-05bb0f8cdfbf> in <module>()
# ----> 1 get_ipython().magic("sql \\copy saludata.defunciones1 from '2021_DEFUNCIONES.csv' with (format CSV, header FALSE, delimiter ';');")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-116> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# <decorator-gen-115> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     335                 _, cur, headers, _ = pgspecial.execute(
#     336                     conn.session.connection.cursor(), statement)[0]
# --> 337                 result = FakeResultProxy(cur, headers)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in __init__(self, cursor, headers)
#     298
#     299     def __init__(self, cursor, headers):
# --> 300         self.fetchall = cursor.fetchall
#     301         self.fetchmany = cursor.fetchmany
#     302         self.rowcount = cursor.rowcount
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'

# %% [markdown]
# Version 1 - Tabla Maestra

# %%
## consulta tabla maestra 
# %%sql 

CREATE TABLE IF NOT EXISTS saludata.maestra AS
(select  -- variables de la tabla que las tenga
        coalesce(morb.num_ide_, mort.num_ide_, numero_documento_madre) as identificacion,
        coalesce(morb.nombre_nacionalidad, mort.nombre_nacionalidad) as nombre_nacionalidad,
        coalesce(morb.cod_dpto_r, mort.cod_dpto_r) as codigo_departamento_r,
        coalesce(morb.cod_mun_r, mort.cod_mun_r) as codigo_municipio_r,
        coalesce(morb.fecha_nto_, mort.fecha_nto_) as fecha_nacimiento,
        coalesce(morb.ocupacion_, mort.ocupacion_) as ocupacion,
        coalesce(morb.tip_ss_, mort.tip_ss_) as tip_ss_,
        coalesce(morb.cod_ase_, mort.cod_ase_) as cod_ase_,
        coalesce(morb.per_etn_, mort.per_etn_) as per_etn_,
        coalesce(morb.estrato_, mort.estrato_) as estrato_, 
        -- variables de mortalidad
         sem_ges_mort, fec_defunsion,  causa_muerte,
        --variables de morbilidad
        fec_not_morb, sem_ges_morb, num_gestac,	num_parvag,	num_cesare,	num_aborto,	num_molas,	num_ectopi,	num_muerto,	num_vivos,	fec_ul_ges,	no_con_pre,	sem_c_pren,
        term_gesta,	moc_rel_tg,	falla_card,	falla_rena,	falla_hepa,	falla_cere,	falla_resp,	falla_coag,	eclampsia,	preclampsi,	choq_septi,	
        hemorragia_obstetrica_severa,	rupt_uteri,	cir_adicio, caus_princ, caus_agrup,
        --variables nacidos vivos
        fecha_nacimiento as fecha_nto_bebe, tiempo_de_gestacion as sem_ges_mort_parto, edad_madre as edad_madre_parto, estado_conyugal_madre, 
        nivel_educativo_madre,  departamento_residencia, municipio_residencia,
        --varaiable de hopitalizacion
        case when hosp.no_hospitalizaciones is null then 0 else hosp.no_hospitalizaciones end as no_hospitalizaciones,
        --variable de consultas
        case when cons.consultas is null then 0 else cons.consultas end as no_consultas,
        --variables de covid
        covid.ini_sin_covid,  gp_gestan_covid, sem_ges_covid

from
  -- Datos de morbilidad (se están duplicando 9 casos)
  (select distinct num_ide_, fec_not as fec_not_morb, area_, nombre_nacionalidad, cod_dpto_r,	cod_mun_r,	area_, ocupacion_,	tip_ss_,	cod_ase_,	per_etn_,	 
          estrato_,	gp_gestan, fecha_nto_, sem_ges_ as sem_ges_morb, 
          num_gestac,	num_parvag,	num_cesare,	num_aborto,	num_molas,	num_ectopi,	num_muerto,	num_vivos,	fec_ul_ges,	no_con_pre,	sem_c_pren,
          term_gesta,	moc_rel_tg,	falla_card,	falla_rena,	falla_hepa,	falla_cere,	falla_resp,	falla_coag,	eclampsia,	preclampsi,	choq_septi,	
          hemorragia_obstetrica_severa,	rupt_uteri,	cir_adicio, caus_princ, caus_agrup
  from saludata.morbilidad --239 registros
  )morb

full outer join
  -- Datos de mortalidad
  (select distinct cast(num_ide_ as varchar) as num_ide_,  fec_not, area_, nombre_nacionalidad, cod_dpto_r,	cod_mun_r,	area_,	ocupacion_, tip_ss_,	cod_ase_,	per_etn_,	 
          estrato_,	gp_gestan, fecha_nto_, sem_ges_ as sem_ges_mort,  
          fec_def_ as fec_defunsion,  cbmte_ as causa_muerte
  from saludata.mortalidad
  )mort
on morb.num_ide_= mort.num_ide_

full outer join
 -- Datos nacidos vivos
  (select distinct numero_documento_madre, fecha_nacimiento, tiempo_de_gestacion, numero_consultas_prenatales, edad_madre, estado_conyugal_madre, nivel_educativo_madre, 
  departamento_residencia, municipio_residencia
  from saludata.nacidos_vivos
  )nacidos
on cast(morb.num_ide_ as varchar)= cast(nacidos.numero_documento_madre as varchar)

left join
  -- Conteo del número de hospitalizaciones para cada mamá
  (select  numero_de_identificacion_del_usuario_en_el_sistema, 
          count(distinct(numero_de_la_factura))no_hospitalizaciones
  from saludata.rpshospitalizacion
  group by tipo_de_documento_de_identificacion_del_usuario, numero_de_identificacion_del_usuario_en_el_sistema
  )hosp
on coalesce(morb.num_ide_, mort.num_ide_, numero_documento_madre) = hosp.numero_de_identificacion_del_usuario_en_el_sistema

left join
  -- Conteo del número de consultas para cada mamá
  (select  numero_de_identificacion_del_usuario,  count(distinct(codigo_de_la_consulta)) as consultas
  from saludata.rpsconsultas
  where finalidad_de_la_consulta in (06)
  group by tipo_de_identificacion_del_usuario, numero_de_identificacion_del_usuario	
  )cons
on coalesce(morb.num_ide_, mort.num_ide_, numero_documento_madre) = cons.numero_de_identificacion_del_usuario

left join
  -- Datos de coronavirus
  (select num_ide_, ini_sin_ as ini_sin_covid,
    gp_gestan as gp_gestan_covid, sem_ges as sem_ges_covid
  from saludata.coronavirus 
  )covid
on coalesce(morb.num_ide_, mort.num_ide_, numero_documento_madre) = covid.num_ide_
order by ini_sin_covid, fec_defunsion, fec_not_morb
);
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# 5417 rows affected.
# []

# %% [markdown]
# Version 2 - Tabla Maestra

# %%
# %%sql
#
# SET DATESTYLE TO
# PostgreSQL,European;
#
# CREATE TABLE IF NOT EXISTS saludata.maestra_v2 AS(
# select numero_documento_madre, resultado, fecha_suceso,	tiempo_de_gestacion,
#       edad_madre,	estado_conyugal_madre,	ultimo_aÑo_aprobado_madre,
#       pais_residencia,	departamento_residencia,
#       nivel_educativo_madre, multiplicidad_embarazo, peso_gramos,
#       coalesce(numero_consultas_prenatales, cons.consultas, 0)numero_consultas,
#       apgar1,	apgar2, municipio_residencia, regimen_seguridad, --solo estan en los nacidos
#       numero_nacidos_vivos, numero_embarazos,
#       mortalidad.fecha_def_mama, mortalidad.causa_muerte_mama ,
#       morbilidad.fec_morbilidad, morbilidad.sem_ges_morb, morbilidad.caus_morbilidad,
#       covid.fecha_covid, hosp.no_hospitalizaciones
#       --count(*)
# from
#     ((select 'Nacido' as resultado, fecha_nacimiento as fecha_suceso,	tiempo_de_gestacion,
#         numero_documento_madre,	substring(edad_madre,1,2) edad_madre,	estado_conyugal_madre,
#         ultimo_aÑo_aprobado_madre,	pais_residencia,	departamento_residencia,	municipio_residencia,
#         numero_embarazos,	regimen_seguridad, multiplicidad_embarazo,
#         min(peso_gramos)peso_gramos, min(apgar1)apgar1,	min(apgar2)apgar2,
#         max(numero_consultas_prenatales) numero_consultas_prenatales,
#         max(nivel_educativo_madre)nivel_educativo_madre,
#         min(numero_hijos_nacidos_vivos)numero_nacidos_vivos
#     from saludata.nacidos_vivos
#     group by resultado, fecha_nacimiento,	tiempo_de_gestacion,
#         numero_documento_madre,	edad_madre,	estado_conyugal_madre,
#         ultimo_aÑo_aprobado_madre,	pais_residencia,	departamento_residencia,	municipio_residencia,
#         municipio_residencia,	numero_embarazos,	regimen_seguridad, multiplicidad_embarazo
#     )
#   union
#     (select 'Fallecido' as resultado, fecha_defuncion, cast(tiempo_gestacion as numeric)tiempo_gestacion,
#           numero_documento_madre, max(substring(edad_madre,1,2))edad_madre, min(estado_conyugal_madre)estado_conyugal_madre,
#           max(ultimo_anio_aprobado_madre)ultimo_anio_aprobado_madre, pais_residencia,	departamento_residencia, municipio_residencia,
#           (min(hijos_nacidos_muertos)+min(hijos_nacidos_vivos))numero_embarazos,
#           regimen_seguridad, multiplicidad,
#           min(peso_feto)peso_feto, ' 'apgar1,	' 'apgar2, null numero_consultas_prenatales,
#           max(nivel_educativo_madre)nivel_educativo_madre,
#           min(hijos_nacidos_vivos) hijos_nacidos_vivos
#     from saludata.defunciones
#     where (date(fecha_defuncion) between '01/01/2021' and'30/06/2021')
#       and (probable_manera_muerte not in('VIOLENTA') or probable_manera_muerte is null)
#       and numero_documento_madre is not null
#       and (tipo_defuncion = 'FETAL')
#     group by resultado, fecha_defuncion, tiempo_gestacion,
#           numero_documento_madre, multiplicidad,regimen_seguridad,
#           pais_residencia,	departamento_residencia,municipio_residencia
#     )
#     )embarazos
#
# left join
#     (select distinct numero_documento_fallecido	, fecha_defuncion as fecha_def_mama, causa_directa as causa_muerte_mama
#     from saludata.defunciones
#     )mortalidad
# on embarazos.numero_documento_madre = mortalidad.numero_documento_fallecido
#
# left join
#   (select num_ide_, max(fec_not)fec_morbilidad, max(sem_ges_)sem_ges_morb, max(caus_princ)caus_morbilidad
#   from saludata.morbilidad
#   where date(fec_not) between '01/06/2020' and'30/06/2021'
#   group by num_ide_
#   )morbilidad
# on embarazos.numero_documento_madre = morbilidad.num_ide_
#
# left join
#   -- Conteo del número de hospitalizaciones para cada mamá
#   (select  numero_de_identificacion_del_usuario_en_el_sistema,
#           count(distinct(numero_de_la_factura))no_hospitalizaciones
#   from saludata.rpshospitalizacion
#   group by numero_de_identificacion_del_usuario_en_el_sistema
#   )hosp
# on embarazos.numero_documento_madre = hosp.numero_de_identificacion_del_usuario_en_el_sistema
#
# left join
#   -- Conteo del número de consultas para cada mamá
#   (select  numero_de_identificacion_del_usuario,  count(distinct(codigo_de_la_consulta)) as consultas
#   from saludata.rpsconsultas
#   where finalidad_de_la_consulta in (06)
#   group by numero_de_identificacion_del_usuario
#   )cons
# on embarazos.numero_documento_madre = cons.numero_de_identificacion_del_usuario
#
# left join
#   -- Datos de coronavirus
#   (select num_ide_, min(ini_sin_) as fecha_covid
#   from saludata.coronavirus
#   group by num_ide_
#   )covid
# on embarazos.numero_documento_madre = covid.num_ide_
#   and embarazos.fecha_suceso > covid.fecha_covid
#
# )
#
# --3281 total
# --602 fallecidos
# --14 embarazos con mamas fallecidas de los cuales 6 aparecen en mortalidad (mortalidad en total son 10)
# --85 mamás con morbilidad
# --125 mamás con covid
# Out:
#  * postgresql://masterbmga:***@dbmaternabmga.cx1teneuqyk1.us-east-2.rds.amazonaws.com/maternabmga
# Done.
# 3281 rows affected.
# []
